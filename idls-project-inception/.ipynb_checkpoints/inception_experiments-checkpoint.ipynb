# %%
import boto3
import requests,time
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_times():
    times=[]
    predict_times=[]
    for i in range(25):
        cur=time.time()
        x=requests.get('https://8ejhh12fx6.execute-api.us-east-1.amazonaws.com/beta/inception-method')
        if x.status_code==200:
            times.append(time.time()-cur)
            predict_times.append(float(json.loads(x.text)['body'][1:-1]))
    return times,predict_times

# %% [markdown]
# ### Warm start Experiments with InceptionV3

# %%
times_512,predict_512=get_times()
plt.plot(times_512)
plt.plot(predict_512)

# %%
times_640,predict_640=get_times()
plt.plot(times_640)
plt.plot(predict_640)

# %%
times_1024,predict_1024=get_times()
plt.plot(times_1024)
plt.plot(predict_1024)

# %%
times_1500,predict_1500=get_times()
plt.plot(times_1500)
plt.plot(predict_1500)

# %%
times_1800,predict_1800=get_times()
plt.plot(times_1800)
plt.plot(predict_1800)

# %%
times_2048,predict_2048=get_times()
plt.plot(times_2048)
plt.plot(predict_2048)

# %%
times_2500,predict_2500=get_times()
plt.plot(times_2500)
plt.plot(predict_2500)

# %%
times_3000,predict_3000=get_times()
plt.plot(times_3000)
plt.plot(predict_3000)

# %%
memories=[512,640,1024,1500,1800,2048,2500,3000]
times_avg=[np.mean(times_512),np.mean(times_640),np.mean(times_1024),np.mean(times_1500),np.mean(times_1800),np.mean(times_2048),np.mean(times_2500),np.mean(times_3000)]
predict_avg=[np.mean(predict_512),np.mean(predict_640),np.mean(predict_1024),np.mean(predict_1500),np.mean(predict_1800),np.mean(predict_2048),np.mean(predict_2500),np.mean(predict_3000)]
times_std=[np.std(times_512),np.std(times_640),np.std(times_1024),np.std(times_1500),np.std(times_1800),np.std(times_2048),np.std(times_2500),np.std(times_3000)]
predict_std=[np.std(predict_512),np.std(predict_640),np.std(predict_1024),np.std(predict_1500),np.std(predict_1800),np.std(predict_2048),np.std(predict_2500),np.std(predict_3000)]
plt.plot(memories,times_avg)
plt.plot(memories,predict_avg)
plt.plot()
# Out:
# []

# %%
plt.errorbar(memories,times_avg,yerr=times_std,label="Latency")
plt.errorbar(memories,predict_avg,yerr=predict_std,label="predict time")
plt.title("Time(s) vs Memory(MB) InceptionV3")
plt.legend()
plt.show()

# %%
import pickle
import os
pickle.dump(times_avg,open('times_avg_inception.pickle','wb'))
pickle.dump(predict_avg,open('predict_avg_inception.pickle','wb'))
pickle.dump(times_std,open('times_std_inception.pickle','wb'))
pickle.dump(predict_std,open('predict_std_inception.pickle','wb'))

# %% [markdown]
# ### Cold start experiment results

# %%
time_512=[22.708,23.508,24.747,23.726,26.224]
plt.plot(time_512)
plt.show()

# %%
time_640=[20.862,24.686,21.124,21.565,22.598]
plt.plot(time_640)
plt.show()

# %%
time_1024=[15.273,15.162,14.748,15.231,15.447]
plt.plot(time_1024)
plt.show()

# %%
time_1500=[13.669,12.861,13.302,14.632,12.356]
plt.plot(time_1500)
plt.show()

# %%
time_1800=[13.396,12.692,15.035,12.506,15.312]
plt.plot(time_1800)
plt.show()

# %%
time_2048=[12.041,12.299,11.939,11.655,11.454]
plt.plot(time_2048)
plt.show()

# %%
time_2500=[14.437,11.819,11.971,11.743,13.007]
plt.plot(time_2500)
plt.show()

# %%
time_3000=[13.667,14.218,13.414,12.839,12.889]
plt.plot(time_3000)
plt.show()

# %%
import pickle
memories=[512,640,1024,1500,1800,2048,2500,3000]
time_warm_avg=pickle.load(open('times_avg_inception.pickle','rb'))
time_warm_std=pickle.load(open('times_std_inception.pickle','rb'))
times_cold_avg=[np.mean(time_512),np.mean(time_640),np.mean(time_1024),np.mean(time_1500),np.mean(time_1800),np.mean(time_2048),np.mean(time_2500),np.mean(time_3000)]
times_cold_std=[np.std(time_512),np.std(time_640),np.std(time_1024),np.std(time_1500),np.std(time_1800),np.std(time_2048),np.std(time_2500),np.std(time_3000)]
plt.errorbar(memories,times_cold_avg,yerr=times_cold_std,label="Latency Cold")
plt.errorbar(memories,time_warm_avg,yerr=time_warm_std,label="Latency Warm")
plt.legend()
plt.show()

# %%
pickle.dump(times_cold_avg,open('times_cold_avg_inception.pickle','wb'))
pickle.dump(times_cold_std,open('times_cold_std_inception.pickle','wb'))

# %% [markdown]
# #### Load testing

# %% [markdown]
# 512 memorry

# %% [markdown]
# ![image.png](attachment:dc4bf743-63e9-40e1-aed1-779b9e327e5c.png)

# %% [markdown]
# ![image.png](attachment:d3506df4-ed66-4788-b232-9f0973433d74.png)

# %% [markdown]
# ![image.png](attachment:6d195e35-8274-40b5-b7d8-13dca8f55c9e.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
fr = open('results_512.txt','rb')
times=[]
for line in fr:
    times.append(float(line))
plt.plot(times)
plt.show()

# %%
times_512_avg = np.mean(times)

# %% [markdown]
# #### 1024

# %% [markdown]
# ![image.png](attachment:4e116486-e535-40cc-b182-2eb12350733e.png)

# %% [markdown]
# ![image.png](attachment:ff953a06-7bd7-45c3-b4cf-4bec727dda17.png)

# %% [markdown]
# ![image.png](attachment:a6fb42e6-cf9c-4f9b-8f3e-60e936b2fe77.png)

# %%
fr = open('results_1024.txt','rb')
times=[]
for line in fr:
    times.append(float(line))
plt.plot(times)
plt.show()
times_1024_avg = np.mean(times)

# %%
api_latency_avg_1024=10991.505580297

# %% [markdown]
# #### 2048

# %% [markdown]
# ![image.png](attachment:7f91eadd-8f5b-48e1-8ec8-057cf67b3d54.png)

# %% [markdown]
# ![image.png](attachment:ae6f544c-a880-4f94-8b4e-b9b6d92a85ac.png)

# %% [markdown]
# ![image.png](attachment:8b309a62-817b-4900-b602-52d0f3fa090e.png)

# %%
fr = open('results_2048.txt','rb')
times=[]
for line in fr:
    times.append(float(line))
plt.plot(times)
plt.show()
times_2048_avg = np.mean(times)

# %%
api_latency_avg_2048=5490.62719373241

# %% [markdown]
# #### 3120

# %% [markdown]
# ![image.png](attachment:a52af355-d539-4e98-a223-a75416224f02.png)

# %% [markdown]
# ![image.png](attachment:784684d4-e8b2-4480-8c7f-f0341ee19c4d.png)

# %% [markdown]
# ![image.png](attachment:b008e5d4-bae0-44ca-9a30-113fe64fae28.png)

# %%
fr = open('results_3120.txt','rb')
times=[]
for line in fr:
    times.append(float(line))
plt.plot(times)
plt.show()
times_3120_avg = np.mean(times)

# %%
api_latency_avg_3120=5585.377366

# %% [markdown]
# #### 4096

# %% [markdown]
# ![image.png](attachment:eb3d08a8-0bd0-4888-a9d3-26e7c3188805.png)

# %% [markdown]
# ![image.png](attachment:ac61699a-fdd4-4bd9-bb3e-44aa8602ad7a.png)

# %% [markdown]
# ![image.png](attachment:922e08fc-236d-46a6-af05-e14d2d876c68.png)

# %%
fr = open('results_4096.txt','rb')
times=[]
for line in fr:
    times.append(float(line))
plt.plot(times)
plt.show()
times_4096_avg = np.mean(times)

# %%
api_latency_avg_4096=5639.253632

# %%
mem=[512,1024,2048,3120,4096]
api_load_avg=[25.00,api_latency_avg_1024/1000,api_latency_avg_2048/1000,api_latency_avg_3120/1000,api_latency_avg_4096/1000]
predict_load_avg=[times_512_avg,times_1024_avg,times_2048_avg,times_3120_avg,times_4096_avg]
plt.plot(mem,api_load_avg)
plt.plot(mem,predict_load_avg)
plt.show()
