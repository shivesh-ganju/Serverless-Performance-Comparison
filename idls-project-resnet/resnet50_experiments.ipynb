# %%
import boto3
import requests,time
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_times():
    times=[]
    predict_times=[]
    for i in range(25):
        cur=time.time()
        x=requests.get('https://5fictvxsi5.execute-api.us-east-1.amazonaws.com/beta/sample-test')
        if x.status_code==200:
            times.append(time.time()-cur)
            predict_times.append(float(x.text[1:-1]))
    return times,predict_times

# %% [markdown]
# ### Warm start Experiments with resnet 50

# %%
times_512,predict_512=get_times()
plt.plot(times_512)
plt.plot(predict_512)

# %%
times_640,predict_640=get_times()
plt.plot(times_640)
plt.plot(predict_640)

# %%
times_1024,predict_1024=get_times()
plt.plot(times_1024)
plt.plot(predict_1024)

# %%
times_1500,predict_1500=get_times()
plt.plot(times_1500)
plt.plot(predict_1500)

# %%
times_1800,predict_1800=get_times()
plt.plot(times_1800)
plt.plot(predict_1800)

# %%
times_2048,predict_2048=get_times()
plt.plot(times_2048)
plt.plot(predict_2048)

# %%
times_2500,predict_2500=get_times()
plt.plot(times_2500)
plt.plot(predict_2500)

# %%
times_3000,predict_3000=get_times()
plt.plot(times_3000)
plt.plot(predict_3000)

# %%
memories=[512,640,1024,1500,1800,2048,2500,3000]
times_avg=[np.mean(times_512),np.mean(times_640),np.mean(times_1024),np.mean(times_1500),np.mean(times_1800),np.mean(times_2048),np.mean(times_2500),np.mean(times_3000)]
predict_avg=[np.mean(predict_512),np.mean(predict_640),np.mean(predict_1024),np.mean(predict_1500),np.mean(predict_1800),np.mean(predict_2048),np.mean(predict_2500),np.mean(predict_3000)]
times_std=[np.std(times_512),np.std(times_640),np.std(times_1024),np.std(times_1500),np.std(times_1800),np.std(times_2048),np.std(times_2500),np.std(times_3000)]
predict_std=[np.std(predict_512),np.std(predict_640),np.std(predict_1024),np.std(predict_1500),np.std(predict_1800),np.std(predict_2048),np.std(predict_2500),np.std(predict_3000)]
plt.plot(memories,times_avg)
plt.plot(memories,predict_avg)
plt.plot()
# Out:
# []

# %%
plt.errorbar(memories,times_avg,yerr=times_std,label="Latency")
plt.errorbar(memories,predict_avg,yerr=predict_std,label="predict time")
plt.title("Time(s) vs Memory(MB) ResNet50")
plt.legend()
plt.show()

# %%
import pickle
import os
pickle.dump(times_512,open('times_512.pickle','wb'))
pickle.dump(times_640,open('times_640.pickle','wb'))
pickle.dump(times_1024,open('times_1024.pickle','wb'))
pickle.dump(times_1500,open('times_1500.pickle','wb'))
pickle.dump(times_1800,open('times_1800.pickle','wb'))
pickle.dump(times_2048,open('times_2048.pickle','wb'))
pickle.dump(times_2500,open('times_2500.pickle','wb'))
pickle.dump(times_3000,open('times_3000.pickle','wb'))

# %%
pickle.dump(predict_512,open('predict_512.pickle','wb'))
pickle.dump(predict_640,open('predict_640.pickle','wb'))
pickle.dump(predict_1024,open('predict_1024.pickle','wb'))
pickle.dump(predict_1500,open('predict_1500.pickle','wb'))
pickle.dump(predict_1800,open('predict_1800.pickle','wb'))
pickle.dump(predict_2048,open('predict_2048.pickle','wb'))
pickle.dump(predict_2500,open('predict_2500.pickle','wb'))
pickle.dump(predict_3000,open('predict_3000.pickle','wb'))

# %%
import pickle
times_512=pickle.load(open('times_512.pickle','rb'))
times_640=pickle.load(open('times_640.pickle','rb'))
times_1024=pickle.load(open('times_1024.pickle','rb'))
times_1500=pickle.load(open('times_1500.pickle','rb'))
times_1800=pickle.load(open('times_1800.pickle','rb'))
times_2048=pickle.load(open('times_2048.pickle','rb'))
times_2500=pickle.load(open('times_2500.pickle','rb'))
times_3000=pickle.load(open('times_3000.pickle','rb'))

# %%
predict_512=pickle.load(open('predict_512.pickle','rb'))
predict_640=pickle.load(open('predict_640.pickle','rb'))
predict_1024=pickle.load(open('predict_1024.pickle','rb'))
predict_1500=pickle.load(open('predict_1500.pickle','rb'))
predict_1800=pickle.load(open('predict_1800.pickle','rb'))
predict_2048=pickle.load(open('predict_2048.pickle','rb'))
predict_2500=pickle.load(open('predict_2500.pickle','rb'))
predict_3000=pickle.load(open('predict_3000.pickle','rb'))

# %%
pickle.dump(times_avg,open('times_avg_resnet.pickle','wb'))
pickle.dump(predict_avg,open('predict_avg_resnet.pickle','wb'))
pickle.dump(times_std,open('times_std_resnet.pickle','wb'))
pickle.dump(predict_std,open('predict_std_resnet.pickle','wb'))

# %% [markdown]
# #### Cold start experiment results

# %%
time_3000 = [13.588,10.683,10.668,11.592,10.523]
plt.plot(time_3000)
plt.show()

# %%
time_512 = [22.708,23.508,24.747,23.726,26.224]
plt.plot(time_512)
plt.show()

# %%
time_512 = [19.143,19.020,19.446,18.613,20.800]
plt.plot(time_512)
plt.show()

# %%
time_640 = [19.886,18.168,16.908,17.497,18.319]
plt.plot(time_640)
plt.show()

# %%
time_1024 = [12.728,14.622,13.188,13.782,13.139]
plt.plot(time_1024)
plt.show()

# %%
time_1500 = [11.897,11.418,11.440,11.779,11.249]
plt.plot(time_1500)
plt.show()

# %%
time_1800 = [11.712,15.255,13.418,11.632,12.473]
plt.plot(time_1800)
plt.show()

# %%
time_2048 = [10.563,11.353,12.314,11.721,10.773]
plt.plot(time_2048)
plt.show()

# %%
time_2500 = [10.736,11.282,11.001,11.031,10.479]
plt.plot(time_2500)
plt.show()

# %%
import pickle
memories=[512,640,1024,1500,1800,2048,2500,3000]
time_warm_avg=pickle.load(open('times_avg_resnet.pickle','rb'))
time_warm_std=pickle.load(open('times_std_resnet.pickle','rb'))
times_cold_avg=[np.mean(time_512),np.mean(time_640),np.mean(time_1024),np.mean(time_1500),np.mean(time_1800),np.mean(time_2048),np.mean(time_2500),np.mean(time_3000)]
times_cold_std=[np.std(time_512),np.std(time_640),np.std(time_1024),np.std(time_1500),np.std(time_1800),np.std(time_2048),np.std(time_2500),np.std(time_3000)]
plt.errorbar(memories,times_cold_avg,yerr=times_cold_std,label="Latency Cold")
plt.errorbar(memories,time_warm_avg,yerr=time_warm_std,label="Latency Warm")
plt.legend()
plt.show()

# %%
pickle.dump(times_cold_avg,open('times_cold_avg_resnet.pickle','wb'))
pickle.dump(times_cold_std,open('times_cold_std_resnet.pickle','wb'))

# %% [markdown]
# #### Load test results

# %% [markdown]
# ![image.png](attachment:82ad1f17-568c-4b70-b506-d3836c725cbb.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
fr = open('results_512.txt','rb')
times=[]
for line in fr:
    times.append(float(line))
plt.plot(times)
plt.show()
times_512_avg = np.mean(times)

# %%
api_latency_avg_512=14358.32883

# %% [markdown]
# ![image.png](attachment:b336ec03-6975-4a17-a4b2-d48a4cbfba26.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
fr = open('results_1024.txt','rb')
times=[]
for line in fr:
    times.append(float(line))
plt.plot(times)
plt.show()
times_1024_avg = np.mean(times)

# %%
api_latency_avg_1024=6910.197627

# %% [markdown]
# ![image.png](attachment:32adaaee-5566-40a7-9eaf-7890122d96a4.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
fr = open('results_2048.txt','rb')
times=[]
for line in fr:
    times.append(float(line))
plt.plot(times)
plt.show()
times_2048_avg = np.mean(times)

# %%
api_latency_avg_2048=4092.23624

# %% [markdown]
# ![image.png](attachment:f8047a83-13df-486e-8c57-fcc988d27277.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
fr = open('results_3120.txt','rb')
times=[]
for line in fr:
    times.append(float(line))
plt.plot(times)
plt.show()
times_3120_avg = np.mean(times)

# %%
api_latency_avg_3120=4357.543634

# %% [markdown]
# ![image.png](attachment:eee97f1c-0887-4d1d-b5d9-a33a87321ac4.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
fr = open('results_4096.txt','rb')
times=[]
for line in fr:
    times.append(float(line))
plt.plot(times)
plt.show()
times_4096_avg = np.mean(times)

# %%
api_latency_avg_4096=3987.80546

# %%
mem=[512,1024,2048,3120,4096]
api_load_avg=[api_latency_avg_512/1000,api_latency_avg_1024/1000,api_latency_avg_2048/1000,api_latency_avg_3120/1000,api_latency_avg_4096/1000]
predict_load_avg=[times_512_avg,times_1024_avg,times_2048_avg,times_3120_avg,times_4096_avg]
plt.plot(mem,api_load_avg,label="Average API Latency")
plt.plot(mem,predict_load_avg,label="Average Inference latency")
plt.title("Resnet50 Load testing result")
plt.legend()
plt.xlabel("Memory(MB)")
plt.ylabel("Time(s)")
plt.show()
